# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd 
import numpy as np

# %%
hod=pd.read_csv("C:/Users/Admin/Downloads/Housing.csv")

# %%
hod.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement
# 0  13300000  7420         4          2        3      yes        no       no  \
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
hod.shape
# Out:
# (545, 13)

# %%
hod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
hod.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000  \
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
sns.pairplot(hod,x_vars =['area','bedrooms','bathrooms','stories','parking'], y_vars='price',size=4,aspect=1,kind='scatter')
plt.show()

# %%
#sns.heatmap(hod.corr(),annot=True)
#plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=hod['area'].values
y=hod['price'].values

# %%
#x

# %%
X=x.reshape(-1,1)
X
# Out:
# array([[ 7420],
#        [ 8960],
#        [ 9960],
#        [ 7500],
#        [ 7420],
#        [ 7500],
#        [ 8580],
#        [16200],
#        [ 8100],
#        [ 5750],
#        [13200],
#        [ 6000],
#        [ 6550],
#        [ 3500],
#        [ 7800],
#        [ 6000],
#        [ 6600],
#        [ 8500],
#        [ 4600],
#        [ 6420],
#        [ 4320],
#        [ 7155],
#        [ 8050],
#        [ 4560],
#        [ 8800],
#        [ 6540],
#        [ 6000],
#        [ 8875],
#        [ 7950],
#        [ 5500],
#        [ 7475],
#        [ 7000],
#        [ 4880],
#        [ 5960],
#        [ 6840],
#        [ 7000],
#        [ 7482],
#        [ 9000],
#        [ 6000],
#        [ 6000],
#        [ 6550],
#        [ 6360],
#        [ 6480],
#        [ 6000],
#        [ 6000],
#        [ 6000],
#        [ 6000],
#        [ 6600],
#        [ 4300],
#        [ 7440],
#        [ 7440],
#        [ 6325],
#        [ 6000],
#        [ 5150],
#        [ 6000],
# ...

# %%
#X=X.reshape(-1,1)
#X

# %%
plt.scatter(X,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y,train_size=0.7, test_size=0.3, random_state=100)

# %%
X_train.shape
# Out:
# (381, 1)

# %%
X_test.shape
# Out:
# (164, 1)

# %%
from sklearn.linear_model import LinearRegression
# Represent LR as lr(Creating LinearRegression Object)
lm=LinearRegression()
# fit model using lr.fit()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= lm.predict(X_test)
y_pred
# Out:
# array([3706048.26680575, 5171689.81131589, 7177082.04000621,
#        4852255.11571753, 4678445.06075959, 4382498.21042581,
#        5425358.54017342, 5425358.54017342, 5547495.33554926,
#        5425358.54017342, 5002577.32541088, 5030762.73972838,
#        3662360.87461362, 9681356.10211634, 4765819.84514385,
#        4424776.33190207, 5876325.16925346, 4267407.76862935,
#        5430056.10922633, 4091248.92914495, 4467054.45337832,
#        4279151.69126164, 3838519.71409801, 5171689.81131589,
#        3790604.50975826, 3849324.12291972, 4471752.02243124,
#        4936811.35867004, 5763583.51198345, 5171689.81131589,
#        3292662.19014904, 4344917.65800248, 4584493.67970125,
#        4067291.32697508, 5190480.08752756, 4720723.18223585,
#        4063063.51482745, 4213385.7245208 , 4058365.94577453,
#        4467054.45337832, 4016087.82429828, 3903346.16702827,
#        5453543.95449092, 3480564.95226573, 3668467.71438241,
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
print("Mean_absolute_error:",mean_absolute_error(y_test, y_pred))
print("Mean_squared_errorr:",mean_squared_error(y_test, y_pred))
print("R_squared:",r2_score(y_test, y_pred)*100)
# Out:
# Mean_absolute_error: 1244367.6725404474
# Mean_squared_errorr: 2767116536598.5312
# R_squared: 29.51839057382545

# %%
y_test.head()
# Out:
# 265    4403000
# 54     7350000
# 171    5250000
# 244    4550000
# 268    4382000
# Name: price, dtype: int64

# %%
y_pred
# Out:
# array([3706048.26680575, 5171689.81131589, 7177082.04000621,
#        4852255.11571753, 4678445.06075959, 4382498.21042581,
#        5425358.54017342, 5425358.54017342, 5547495.33554926,
#        5425358.54017342, 5002577.32541088, 5030762.73972838,
#        3662360.87461362, 9681356.10211634, 4765819.84514385,
#        4424776.33190207, 5876325.16925346, 4267407.76862935,
#        5430056.10922633, 4091248.92914495, 4467054.45337832,
#        4279151.69126164, 3838519.71409801, 5171689.81131589,
#        3790604.50975826, 3849324.12291972, 4471752.02243124,
#        4936811.35867004, 5763583.51198345, 5171689.81131589,
#        3292662.19014904, 4344917.65800248, 4584493.67970125,
#        4067291.32697508, 5190480.08752756, 4720723.18223585,
#        4063063.51482745, 4213385.7245208 , 4058365.94577453,
#        4467054.45337832, 4016087.82429828, 3903346.16702827,
#        5453543.95449092, 3480564.95226573, 3668467.71438241,
# ...

# %%
##################################__PRACTICE SLR ON CAR DATA__##########################################################

# %%
car=pd.read_csv("D:\Datasets for Practice\cardata.csv")

# %%
car.head()
# Out:
#   Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven
# 0     ritz  maruti suzuki  2014           3.35           5.59       27000  \
# 1      sx4  maruti suzuki  2013           4.75           9.54       43000
# 2     ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3  wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4    swift  maruti suzuki  2014           4.60           6.87       42450
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol      Dealer       Manual      0
# 1    Diesel      Dealer       Manual      0
# 2    Petrol      Dealer       Manual      0
# 3    Petrol      Dealer       Manual      0
# 4    Diesel      Dealer       Manual      0

# %%
car['CurrentYear']=2023

# %%
car.head()
# Out:
#   Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven
# 0     ritz  maruti suzuki  2014           3.35           5.59       27000  \
# 1      sx4  maruti suzuki  2013           4.75           9.54       43000
# 2     ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3  wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4    swift  maruti suzuki  2014           4.60           6.87       42450
#
#   Fuel_Type Seller_Type Transmission  Owner  CurrentYear
# 0    Petrol      Dealer       Manual      0         2023
# 1    Diesel      Dealer       Manual      0         2023
# 2    Petrol      Dealer       Manual      0         2023
# 3    Petrol      Dealer       Manual      0         2023
# 4    Diesel      Dealer       Manual      0         2023

# %%
car['No.of Years']=car['CurrentYear']-car['Year']
car.head()
# Out:
#   Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven
# 0     ritz  maruti suzuki  2014           3.35           5.59       27000  \
# 1      sx4  maruti suzuki  2013           4.75           9.54       43000
# 2     ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3  wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4    swift  maruti suzuki  2014           4.60           6.87       42450
#
#   Fuel_Type Seller_Type Transmission  Owner  CurrentYear  No.of Years
# 0    Petrol      Dealer       Manual      0         2023            9
# 1    Diesel      Dealer       Manual      0         2023           10
# 2    Petrol      Dealer       Manual      0         2023            6
# 3    Petrol      Dealer       Manual      0         2023           12
# 4    Diesel      Dealer       Manual      0         2023            9

# %%
car.shape
# Out:
# (301, 12)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   company        301 non-null    object
#  2   Year           301 non-null    int64
#  3   Selling_Price  301 non-null    float64
#  4   Present_Price  301 non-null    float64
#  5   Kms_Driven     301 non-null    int64
#  6   Fuel_Type      301 non-null    object
#  7   Seller_Type    301 non-null    object
#  8   Transmission   301 non-null    object
#  9   Owner          301 non-null    int64
#  10  CurrentYear    301 non-null    int64
#  11  No.of Years    301 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 28.3+ KB

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000  \
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000
#
#        CurrentYear  No.of Years
# count        301.0   301.000000
# mean        2023.0     9.372093
# std            0.0     2.891554
# min         2023.0     5.000000
# 25%         2023.0     7.000000
# 50%         2023.0     9.000000
# 75%         2023.0    11.000000
# ...

# %%
sns.pairplot(car,x_vars =['Present_Price','Kms_Driven','No.of Years'], y_vars='Selling_Price',size=4,aspect=1,kind='scatter')
plt.show()

# %%
#sns.heatmap(car.corr(),annot=True)
#plt.show()

# %%
x=car['No.of Years'].values
y=car['Selling_Price'].values

# %%
#X=np.array(car['Kms_Driven'])
#X

# %%
X=x.reshape(-1,1)
X
# Out:
# array([[ 9],
#        [10],
#        [ 6],
#        [12],
#        [ 9],
#        [ 5],
#        [ 8],
#        [ 8],
#        [ 7],
#        [ 8],
#        [ 6],
#        [ 8],
#        [ 8],
#        [ 8],
#        [14],
#        [ 7],
#        [ 8],
#        [ 7],
#        [ 8],
#        [13],
#        [ 7],
#        [ 6],
#        [12],
#        [ 9],
#        [10],
#        [12],
#        [10],
#        [ 6],
#        [13],
#        [ 8],
#        [11],
#        [12],
#        [ 9],
#        [ 9],
#        [ 9],
#        [12],
#        [ 8],
#        [20],
#        [ 7],
#        [20],
#        [ 7],
#        [ 9],
#        [15],
#        [ 9],
#        [11],
#        [ 9],
#        [10],
#        [17],
#        [ 8],
#        [ 6],
#        [11],
#        [ 8],
#        [ 6],
#        [10],
#        [18],
#        [14],
#        [ 8],
#        [13],
#        [ 9],
#        [ 9],
#        [10],
#        [ 8],
#        [ 9],
#        [ 8],
#        [ 6],
#        [ 9],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,train_size=0.7,test_size=0.3,random_state=100)

# %%
X_train.shape
# Out:
# (210, 1)

# %%
X_test.shape
# Out:
# (91, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= lm.predict(X_test)
y_pred
# Out:
# array([2.33115894, 3.41548843, 5.58414741, 3.05404527, 4.49981792,
#        4.49981792, 5.94559057, 3.05404527, 5.22270424, 5.22270424,
#        5.22270424, 4.49981792, 4.49981792, 4.13837476, 5.94559057,
#        5.22270424, 1.96971578, 3.77693159, 5.94559057, 5.58414741,
#        5.94559057, 5.22270424, 5.22270424, 5.22270424, 5.94559057,
#        5.22270424, 5.94559057, 5.22270424, 5.58414741, 5.58414741,
#        4.86126108, 5.94559057, 5.22270424, 5.22270424, 5.58414741,
#        4.49981792, 4.13837476, 5.58414741, 4.13837476, 5.22270424,
#        5.94559057, 4.49981792, 5.22270424, 5.22270424, 5.58414741,
#        5.22270424, 5.94559057, 3.41548843, 4.86126108, 5.94559057,
#        5.94559057, 4.86126108, 4.86126108, 4.86126108, 4.49981792,
#        4.86126108, 5.58414741, 5.94559057, 4.13837476, 3.41548843,
#        1.96971578, 4.86126108, 3.77693159, 5.94559057, 4.86126108,
#        4.13837476, 4.13837476, 5.58414741, 5.58414741, 5.58414741,
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
print("Mean_absolute_error:",mean_absolute_error(y_test, y_pred))
print("Mean_squared_errorr:",mean_squared_error(y_test, y_pred))
print("R_squared:",r2_score(y_test, y_pred))
# Out:
# Mean_absolute_error: 3.3177302180827812
# Mean_squared_errorr: 24.151715469502715
# R_squared: 0.07424793485771308

# %%
#y_test

# %%
#y_pred
